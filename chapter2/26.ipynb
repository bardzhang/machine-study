# %%
import torch
from torch.distributions import multinomial

# %%
faire_probs=torch.ones([6])/6
multinomial.Multinomial(1,faire_probs).sample()
# Out:
# tensor([0., 0., 0., 1., 0., 0.])

# %%
counts=multinomial.Multinomial(1000,faire_probs).sample()
counts/1000
# Out:
# tensor([0.1480, 0.1610, 0.1770, 0.1770, 0.1790, 0.1580])
